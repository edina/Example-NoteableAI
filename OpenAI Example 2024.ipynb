# %%
import openai
import os

# Set your API key
openai.api_key = os.getenv("OPENAI_API_KEY", "YOUR-OPEN-AI-KEY")

# Ensure you have the latest version of the OpenAI package
# pip install --upgrade openai if necessary

# Create a completion request
completion = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "user", "content": "How do I output all files in a directory using Python?"}
    ]
)

# Print the response
print(completion['choices'][0]['message']['content'].strip())

# %%
# Import necessary libraries
# !pip install openai
# Load API key from .env file
API_KEY = os.getenv("API_KEY")

# Set the API key for OpenAI
openai.api_key = "API-KEY"


# Define the prompt
prompt = "Write a short limerick for the teaching and learning community."

def generate_response(prompt):
    while True:
        try:
            # Make the API request and get the response
            response = openai.Completion.create(
              engine="gpt-3.5-turbo-instruct",
              prompt=prompt,
              max_tokens=1000
            )
            return response.choices[0].text.strip()
        except Exception as e:
            print(f"An error occurred: {e}")
            time.sleep(3)

# Generate the response
response_text = generate_response(prompt)

# Print the response text
print(response_text)

# %%
# Set the API key for OpenAI
openai.api_key = "YOUR-API-KEY"

import random

def ai_magic():
    responses = [
        "It is certain.",
        "It is decidedly so.",
        "Without a doubt.",
        "Yes - definitely.",
        "You may rely on it.",
        "As I see it, yes.",
        "Most likely.",
        "Outlook good.",
        "Yes.",
        "Signs point to yes.",
        "Reply hazy, try again.",
        "Ask again later.",
        "Better not tell you now.",
        "Cannot predict now.",
        "Concentrate and ask again.",
        "Don't count on it.",
        "My reply is no.",
        "My sources say no.",
        "Outlook not so good.",
        "Very doubtful."
    ]
    
    print("Welcome to AI Magic 8 Ball! Ask your question:")
    _ = input()
    
    print("AI Magic 8 Ball says:", random.choice(responses))

ai_magic()
